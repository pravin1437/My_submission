# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<H1/>

# %% [markdown]
# <B>VANKUDOTH PRAVEEN<B/> <br/>
# I'm a anspiring data scientist

# %% [markdown]
# <i>"I'm interested in Datascience because I wanna secure a high package salaried job in my carrer"<i/> <br>
# <i>I would like to learn more skills regarding datascience throughcoursera platform<i/>

# %% [markdown]
# <h3>Following code adds two numbers<h3/>

# %%
a = 10
b = 20
c = a+b
print(c)
# Out:
# 30

# %% [markdown]
# <B>BELOW IS HORIZONTAL LINE<B/> <BR/>
#     *** <BR/>
#  <B>BELOW IS NUMBERED LIST<B/> <BR/>
# 1. HEY
# 1. HELLO
#      <BR/>
# <B>BELOW IS HORIZONTAL LINE<B/> <BR/>
#  - Bulleted item
